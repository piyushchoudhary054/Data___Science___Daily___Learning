# %%
# pandas:-> it is a library which is used to manipulate the data, and analys the data
# pandas is built on the top of numpy library in python
import pandas as pd

# %%
# to read csv file we use the read_cvs method 
#read_csv('path_of_file')
pd.read_csv('./world.sql')

# %%
# pandas have two different data type 
#1 series it is a primary data structure that is built on the top of numpy
# arrays , a pandas serires is a 1d that add addition feature like exolicit idexing nd integrate misising dagta handling making it ideal for data analysys
# 2 => dataframe

# %%
import numpy as np
# created serirs wid the help of numpy array
pd.Series(np.array([1,2,3,4]),index = ['a','b','c','d'])

# %%
li = [1,2,3,4]
li_idx = ['a','b','c','d']
pd.Series(li, index=li_idx)

# %%
# creating a series witht the help of dictionary
d = {
    'a' : 10,
    'b' : 20,
    'c' : 30
# when we create any series with the help of dictionary 
# key ->index , value ->value

}
pd.Series(d)

# %%
# values is used to retrieve the values of the series
# it returns the values in the form of a numpy array
s1 = pd.Series([1,2,3,4])
s1.values

# %%
# .index is a method to find all the indices the serurs
s1.index

# %%
s1.dtype

# %%
# vector operation
s1 = pd.Series([1,2,3,4])
s1 = pd.Series([5,6,7,8])
s1+s1

# %%
s1 **2

# %%
s = pd.Series(np.arange(1,13))
s[s > 5]

# %%
s[s%2 == 0]

# %%
#DataFrame isme rows and columsn mai kam hota hai
# ->it is a2d  table,like data sructure used to manupuralte and analays
# it have mainly three thing that are -> data, rows,columns (names similar to sql data)

#creating dataframes with dictionary
st_Dt = {
    'name':['Rahul','Aman','Naman'],
    'sub' : ['Math','chem','sci'],
    'marks':[50,60,90],
    'Add' : ['jaipur','biwani','mundru']
}
pd.DataFrame(st_Dt)

# %%
st = [
    ['rahul','math','50','jaipur'],
    ['aman','math','50','jaipur'],
    ['naman','math',' '  ,'jaipur']
]
df =pd.DataFrame(st,columns = ['name','sub','marks','loc'])

# %%
# converting a data frame to csv format
df.to_csv('st')

# %%
#pandas ->
