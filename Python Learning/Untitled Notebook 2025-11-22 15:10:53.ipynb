# %%
#you have been provide number of days means user give 
#we have to calucalte the total amount received by the user 
# mon -1$ user reciec
#tue -2$
#--7$ till sund
## for the next week the monday will become the 2$ received

# %%
strs = ["eat","tea","tan","ate","nat","bat"]
new = []
for i in strs:
    # new.append(list(i))
    li = list(i)
    if li not in new:
    
print(new)
