# %%
#Write a program to print all natural numbers from 1 to n. – using while

num = int(input("enter the number till where you want to print"))
i =1
while(i<=num):
    print(i)
    i+=1

# %%
# Write a program to print all natural numbers in reverse (from n to 1). –
# using while loop

num = int(input("enter the number"))
while(num>0):
    print(num)
    num -= 1

# %%
# Write a program to print all alphabets from a to z. – using while loop
i = 65
while(i<91):
    print(chr(i))
    i +=1

# %%
#to print event number from 1 to 100
i =1
while(i<=101):
    if(i%2==0):
        print(i)
    i +=1

# %%
# wap to praint  sum of all odd number from 1 to n

num = int(input("enter the  number"))
sum =0
i = 1
while(i<=num):
    if(i%2 != 0):
        sum += i
    i = i+1   
print("the sum of odd number is",sum)

# %%
#wap to count the number of digits in a number

num = int(input("enter the number"))
count = 0

while(num>0):
    if(num == 0):
        break
    count += 1
    num = num //10
   
    
print(count)

# %%
#to calculate the sum of digits in a nunbe

num = int(input("enter the number"))
sum = 0
temp = num
while(num>0):
    if(num == 0):
        break
   
    temp = num %10
    num = num //10
    sum += temp
print(sum)

# %%
#wap to find the first and last digit of a number

num = int(input("enter the number"))
first =0
last = 0
temp = num
while(num>0):
    if(num <= 9):
      first = num
      break
    num = num//10
    

last = temp%10
print(f"the first digit of {temp} is {num} and last digit is {last} ")
print("the sum of first and last digit number is",first + last)

# %%
# 10.Write a program to enter a number and print its reverse.

num = int(input("enter the number"))
rev = 0
temp = num
last = 0
while(num>0):
    if(num == 0):
        break
    last  = num%10
    rev = rev*10 + last
    num = num//10
print("the number after reverse is",rev)

# %%
#wap to find the power of the numner
num = int(input("enter the number"))
power = int(input("enter the power"))
temp = num
i = 1
while(i<power):
    num = num*temp
    i += 1
print(num)

# %%
#wap tp find all factors of a number
num = int(input("enter the number"))
i = 1
while(i<=num):

    if(num%i == 0):
        print("the factor of",num,"is",i)
    i +=1

# %%
#wap to calculate tha factorail of number
num = int(input("enter the number"))
factorial = 1
i =1
while(i<=num):
    factorial = factorial*i
    i +=1
print(factorial)

# %%
'''15.Write a program to check whether a number is Prime number or not.'''
num = int(input("enter the number"))
i = 2
while(i<num):
    if(num%i == 0):
        print("the number is not prime")
        break
    i += 1
else:
    print("the number is prime")
