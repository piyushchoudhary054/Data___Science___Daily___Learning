# %%
li = [10,20,30,1,2,4,3]
max1 = 1
cnt = 1
j =1
for i in range(len(li)-1):
    
    if li[i] < li[j+i]:
        cnt +=1
    else:
        if max1 < cnt:
            max1 = cnt
            cnt = 1
print(max1)

# %%
x = "abcab"  
s = len(x)
res = ''

d = {}
j = 0
i = 0

while(i<s):
    res = res + x[j] 
    if res not in d: 
        d[res] =1
         
    else:    
           d[res]+=1   
    j+=1           
       
    if j == s:
        i+=1 
        j = i
        res = ''     
   
          
print(d)

# %%
s = "abcabccbacba"
d = {}
max1 = 1
j = i = 0
res = ''
while i < len(s) - 1:
    if s[j] != s[j + 1]:
        res = res + s[j]
        if res not in d:
            d[res] = 1
        else:
            d[res] += 1
        j += 1
        if j == len(s):
            i += 1
            j = i
            res = ''
    else:
        j += 1
        if j == len(s):
            i += 1
            j = i
            res = ''
x = len(s)
print(x)
