# %%
# import the file so we can perforn or do sql here
df = spark.read.format("csv").option("header", "true").load("/path/to/your/file.csv")
df.createOrReplaceTempView("my_table")
